# %%
import json
import pandas as pd
import nltk
import boto3
import numpy as np
import seaborn as sns

# %%
dataset_folder = "yelp_dataset_challenge_academic_dataset"
business_datafile = "yelp_academic_dataset_business.json"
review_datafile = "yelp_academic_dataset_review.json"
user_datafile = "yelp_academic_dataset_user.json"

# %% [markdown]
# Reading in the buisness data

# %%
business_data = pd.read_json(f"../{dataset_folder}/{business_datafile}", lines=True, typ="frame", orient="columns")
business_data.drop(["hours", "open", "full_address", "neighborhoods", "longitude", "latitude", "attributes", "type", "review_count"], axis=1, inplace=True)
business_data.set_index("business_id", inplace=True, verify_integrity=True)
business_data["categories"] = business_data["categories"].apply(lambda x: set(x))

# %% [markdown]
# Filtering out Chinese restaurants

# %%
ch_rest_data = business_data[business_data["categories"].map(lambda x: "Restaurants" in x and "Chinese" in x)]

# %%
ch_rest_data
# Out:
#                                                         categories  \
# business_id
# RgDg-k9S5YD_BaxMckifkg                      {Restaurants, Chinese}
# UgjVZTSOaYoEvws_lAP_Dw                      {Restaurants, Chinese}
# MKsb2VpLB-0UBODcInDsSw                      {Restaurants, Chinese}
# KW6HejC-67KSL9J8Cz1dSw                      {Restaurants, Chinese}
# wl-7A4jC0f27MOEmW-XTbQ                      {Restaurants, Chinese}
# ...                                                            ...
# MJLe4pP-0ZOFHuFt0CIoRw                      {Restaurants, Chinese}
# 8T4aPvtpugzUxJc-DVrLHg                      {Restaurants, Chinese}
# 4Db74Jsyp81bei99fo-3Xg  {Mongolian, Restaurants, Chinese, Buffets}
# kiA-L7r9uHh2bqUPxuCzNQ  {Restaurants, Thai, Asian Fusion, Chinese}
# O5BaxsfXVo7kwX1YnjyvzA            {Szechuan, Restaurants, Chinese}
#
#                               city                          name state  stars
# business_id
# RgDg-k9S5YD_BaxMckifkg   De Forest   Chang Jiang Chinese Kitchen    WI    4.0
# UgjVZTSOaYoEvws_lAP_Dw  Mc Farland  Main Moon Chinese Restaurant    WI    3.5
# MKsb2VpLB-0UBODcInDsSw   Middleton              China Wok Buffet    WI    2.5
# KW6HejC-67KSL9J8Cz1dSw   Middleton             Chin's Asia Fresh    WI    3.0
# wl-7A4jC0f27MOEmW-XTbQ   Middleton        Grand China Restaurant    WI    3.0
# ...                            ...                           ...   ...    ...
# MJLe4pP-0ZOFHuFt0CIoRw   Las Vegas      A & K Chinese Restaurant    NV    4.0
# 8T4aPvtpugzUxJc-DVrLHg   Las Vegas                 Dumpling King    NV    4.5
# 4Db74Jsyp81bei99fo-3Xg     Madison                  World Buffet    WI    2.5
# kiA-L7r9uHh2bqUPxuCzNQ   Las Vegas                Oriental House    NV    4.5
# O5BaxsfXVo7kwX1YnjyvzA   Las Vegas              Szechuan Express    NV    4.0
#
# [1002 rows x 5 columns]

# %% [markdown]
# Fetching the reviews on the filtered restaurants

# %%
review_data = pd.read_json(f"../{dataset_folder}/{review_datafile}", lines=True, typ="frame", orient="columns")
review_data.drop(["date", "type"], axis=1, inplace=True)
review_data.set_index("review_id", inplace=True)

# %%
complete_data = review_data.join(ch_rest_data, how="inner", on="business_id", lsuffix="_rev", rsuffix="_res")

# %% [markdown]
# Calculating the total votes received by the review

# %%
complete_data["tot_votes"] = complete_data["votes"].map(lambda obj: obj["funny"] + obj["useful"] + obj["cool"])
complete_data.drop("votes", inplace=True, axis=1)

# %% [markdown]
# Converting the reviews texts into sentences so we can find the ones containing our dishes

# %%
def sent_tokenise_reviews(review_txt):
    regex_tk = nltk.tokenize.RegexpTokenizer(pattern=r"[.?!;,\n]+" ,gaps=True, discard_empty=True)
    sentences = [s.strip() for s in regex_tk.tokenize(review_txt)]
    
    return sentences

# %%
complete_data["review"] = complete_data["text"].map(sent_tokenise_reviews)
complete_data.drop("text", axis=1, inplace=True)

# %% [markdown]
# We also want to factor in the popularity of the user in our score for the review.

# %%
user_data = pd.read_json(f"../{dataset_folder}/{user_datafile}", lines=True, typ="frame", orient="columns")
user_data.drop(["yelping_since", "votes", "average_stars", "type", "compliments", "elite", "name"], axis=1, inplace=True)
user_data.set_index("user_id", inplace=True)

# %% [markdown]
# Joining this data with our review and retaurant table

# %%
complete_data = complete_data.join(user_data, how="inner", on="user_id")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-b893d3768c1a> in <module>
# ----> 1 complete_data = complete_data.join(user_data, how="inner", on="user_id")
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7244         # For SparseDataFrame's benefit
#    7245         return self._join_compat(
# -> 7246             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7247         )
#    7248
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7267                 right_index=True,
#    7268                 suffixes=(lsuffix, rsuffix),
# -> 7269                 sort=sort,
#    7270             )
#    7271         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      81         validate=validate,
#      82     )
# ---> 83     return op.get_result()
#      84
#      85
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     646
#     647         llabels, rlabels = _items_overlap_with_suffix(
# --> 648             ldata.items, lsuf, rdata.items, rsuf
#     649         )
#     650
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    2009         raise ValueError(
#    2010             "columns overlap but no suffix specified: "
# -> 2011             "{rename}".format(rename=to_rename)
#    2012         )
#    2013
#
# ValueError: columns overlap but no suffix specified: Index(['review_count', 'friends', 'fans'], dtype='object')

# %% [markdown]
# This is what our final processed dataset looks like

# %%
complete_data
# Out:
#                                        user_id  stars_rev  \
# review_id
# ZYaS2P5EmK9DANxGTV48Tw  u5xcw6LCnnMhddoxkRIgUA          5
# uOLM0vvnFdp468ofLnszTA  kj18hvJRPLepZPNL7ySKpg          3
# 8EjIXDrV5QjmjU52PePGkw  kj18hvJRPLepZPNL7ySKpg          2
# v4jw2p9EdIIU5EyNUR7eJA  kj18hvJRPLepZPNL7ySKpg          4
# 1yaTswITBDOQXCttxw7lwA  kj18hvJRPLepZPNL7ySKpg          4
# ...                                        ...        ...
# AX5EBWZQ8hnv-EAXb6LaGQ  yKXsbgzpI3710TNuXZUdmQ          5
# MGZ5hFzc0zx0doMNZ77FOw  nVLjR4wlwRqy2pDevDyczw          5
# 5O8hdZBAxKqxaJwzr2baTw  C0wuzY2sMy2wFw5AKNf0Tw          4
# GCNMuWjMTPuscr2NmZ947Q  pMXXX6AbUXgivkju9S7YDQ          5
# rBV7PA9Z_ts_lAbrlPuHjA  jgayAxICMagHshhKleu1bA          3
#
#                                    business_id  tot_votes  \
# review_id
# ZYaS2P5EmK9DANxGTV48Tw  RgDg-k9S5YD_BaxMckifkg          0
# uOLM0vvnFdp468ofLnszTA  RgDg-k9S5YD_BaxMckifkg          0
# 8EjIXDrV5QjmjU52PePGkw  unXHmjewHGeWQwJr74Sy9g          0
# v4jw2p9EdIIU5EyNUR7eJA  unXHmjewHGeWQwJr74Sy9g          1
# 1yaTswITBDOQXCttxw7lwA  DR4xcr3eJ0vfYRomvx036w          1
# ...                                        ...        ...
# AX5EBWZQ8hnv-EAXb6LaGQ  kiA-L7r9uHh2bqUPxuCzNQ          1
# MGZ5hFzc0zx0doMNZ77FOw  kiA-L7r9uHh2bqUPxuCzNQ          1
# 5O8hdZBAxKqxaJwzr2baTw  kiA-L7r9uHh2bqUPxuCzNQ          2
# GCNMuWjMTPuscr2NmZ947Q  kiA-L7r9uHh2bqUPxuCzNQ          3
# rBV7PA9Z_ts_lAbrlPuHjA  O5BaxsfXVo7kwX1YnjyvzA          0
#
#                                                         categories       city  \
# review_id
# ZYaS2P5EmK9DANxGTV48Tw                      {Restaurants, Chinese}  De Forest
# uOLM0vvnFdp468ofLnszTA                      {Restaurants, Chinese}  De Forest
# 8EjIXDrV5QjmjU52PePGkw                      {Restaurants, Chinese}    Madison
# v4jw2p9EdIIU5EyNUR7eJA                      {Restaurants, Chinese}    Madison
# 1yaTswITBDOQXCttxw7lwA                      {Restaurants, Chinese}    Madison
# ...                                                            ...        ...
# AX5EBWZQ8hnv-EAXb6LaGQ  {Restaurants, Thai, Asian Fusion, Chinese}  Las Vegas
# MGZ5hFzc0zx0doMNZ77FOw  {Restaurants, Thai, Asian Fusion, Chinese}  Las Vegas
# 5O8hdZBAxKqxaJwzr2baTw  {Restaurants, Thai, Asian Fusion, Chinese}  Las Vegas
# GCNMuWjMTPuscr2NmZ947Q  {Restaurants, Thai, Asian Fusion, Chinese}  Las Vegas
# rBV7PA9Z_ts_lAbrlPuHjA            {Szechuan, Restaurants, Chinese}  Las Vegas
#
#                                                name state  stars_res  \
# review_id
# ZYaS2P5EmK9DANxGTV48Tw  Chang Jiang Chinese Kitchen    WI        4.0
# uOLM0vvnFdp468ofLnszTA  Chang Jiang Chinese Kitchen    WI        4.0
# 8EjIXDrV5QjmjU52PePGkw                    China Inn    WI        3.0
# v4jw2p9EdIIU5EyNUR7eJA                    China Inn    WI        3.0
# 1yaTswITBDOQXCttxw7lwA        Wah Kee Wonton Noodle    WI        3.5
# ...                                             ...   ...        ...
# AX5EBWZQ8hnv-EAXb6LaGQ               Oriental House    NV        4.5
# MGZ5hFzc0zx0doMNZ77FOw               Oriental House    NV        4.5
# 5O8hdZBAxKqxaJwzr2baTw               Oriental House    NV        4.5
# GCNMuWjMTPuscr2NmZ947Q               Oriental House    NV        4.5
# rBV7PA9Z_ts_lAbrlPuHjA             Szechuan Express    NV        4.0
#
#                                                                    review  \
# review_id
# ZYaS2P5EmK9DANxGTV48Tw  [I really like both Chinese restaurants in tow...
# uOLM0vvnFdp468ofLnszTA  [Above average takeout with friendly staff, Th...
# 8EjIXDrV5QjmjU52PePGkw  [Uninspired Chinese food from very nice people...
# v4jw2p9EdIIU5EyNUR7eJA  [China Inn seems to have improved since I last...
# 1yaTswITBDOQXCttxw7lwA  [This is where we go for comfort food, As you ...
# ...                                                                   ...
# AX5EBWZQ8hnv-EAXb6LaGQ  [My girlfriend came here with her mom, and tho...
# MGZ5hFzc0zx0doMNZ77FOw  [I have been craving pad Thai lately and tryin...
# 5O8hdZBAxKqxaJwzr2baTw  [We VegaS-ites are lucky and if you are anywhe...
# GCNMuWjMTPuscr2NmZ947Q  [Stopped by on 7-12-2014 by chance after simpl...
# rBV7PA9Z_ts_lAbrlPuHjA  [Food is good, but price is on the high side i...
#
#                         review_count  \
# review_id
# ZYaS2P5EmK9DANxGTV48Tw            21
# uOLM0vvnFdp468ofLnszTA            75
# 8EjIXDrV5QjmjU52PePGkw            75
# v4jw2p9EdIIU5EyNUR7eJA            75
# 1yaTswITBDOQXCttxw7lwA            75
# ...                              ...
# AX5EBWZQ8hnv-EAXb6LaGQ             1
# MGZ5hFzc0zx0doMNZ77FOw             1
# 5O8hdZBAxKqxaJwzr2baTw             1
# GCNMuWjMTPuscr2NmZ947Q            25
# rBV7PA9Z_ts_lAbrlPuHjA             2
#
#                                                                   friends  \
# review_id
# ZYaS2P5EmK9DANxGTV48Tw   [Xiprzd4TvJcZnVHGPdDh1A, vNMHIyT76krWH3LXevQ96A]
# uOLM0vvnFdp468ofLnszTA  [3T66OaLFT0xAnqW4IGNwrQ, dFSg9ZUwdvXO1c1ZACgZz...
# 8EjIXDrV5QjmjU52PePGkw  [3T66OaLFT0xAnqW4IGNwrQ, dFSg9ZUwdvXO1c1ZACgZz...
# v4jw2p9EdIIU5EyNUR7eJA  [3T66OaLFT0xAnqW4IGNwrQ, dFSg9ZUwdvXO1c1ZACgZz...
# 1yaTswITBDOQXCttxw7lwA  [3T66OaLFT0xAnqW4IGNwrQ, dFSg9ZUwdvXO1c1ZACgZz...
# ...                                                                   ...
# AX5EBWZQ8hnv-EAXb6LaGQ                           [WYLynFCS994Vsb8T6OE7FA]
# MGZ5hFzc0zx0doMNZ77FOw                                                 []
# 5O8hdZBAxKqxaJwzr2baTw                                                 []
# GCNMuWjMTPuscr2NmZ947Q                                                 []
# rBV7PA9Z_ts_lAbrlPuHjA                                                 []
#
#                         fans
# review_id
# ZYaS2P5EmK9DANxGTV48Tw     1
# uOLM0vvnFdp468ofLnszTA     3
# 8EjIXDrV5QjmjU52PePGkw     3
# v4jw2p9EdIIU5EyNUR7eJA     3
# 1yaTswITBDOQXCttxw7lwA     3
# ...                      ...
# AX5EBWZQ8hnv-EAXb6LaGQ     0
# MGZ5hFzc0zx0doMNZ77FOw     0
# 5O8hdZBAxKqxaJwzr2baTw     0
# GCNMuWjMTPuscr2NmZ947Q     0
# rBV7PA9Z_ts_lAbrlPuHjA     0
#
# [38716 rows x 13 columns]

# %% [markdown]
# Now we'll load the list of chinese dish names that were extracted in Task 3

# %%
dishes = pd.read_csv("chinese_phrases.csv")
dishes
# Out:
#                         Dish  confidence
# 0                    dim sum    1.000000
# 1       sweet and sour sauce    0.999881
# 2                 fried rice    0.999524
# 3                 sesame oil    0.999523
# 4                    el topo    0.999448
# ...                      ...         ...
# 112947                 a and    0.000000
# 112948                   a a    0.000000
# 112949                  a 's    0.000000
# 112950             's review    0.000000
# 112951                's and    0.000000
#
# [112952 rows x 2 columns]

# %% [markdown]
# This list is quite long. Since its already sorted by confidence lets select the top 50 dishes

# %%
dishes = dishes.head(50)

# %% [markdown]
# Now we need to find all the sentences in the reviews that contains the names of these dishes and run them through a sentiment analyser. For this excercise I decided to the __AWS Comprehend__ service that provides a sentiment analyser out of the box. We'll calculate the review sentiment for each dish, restaurant pair so that we can figure out which dish is good in which restaurant

# %% [markdown]
# Fetching the sentences for each review which contains the dishes we are interested in. Writing these out to a file since its a long operation and I can easily load a data from disk when I need it

# %%
with open("./output/dish_reviews.csv", "w", encoding="utf-8") as f:
    f.write("dish,review_id,business_id,sentences\n")
    for dish in dishes["Dish"]:
        for idx, row in complete_data.iterrows():
            rel_sentences = ""
            for sentence in row["review"]:
                if sentence.find(dish) > -1:
                    rel_sentences = rel_sentences + sentence + "|"
            if rel_sentences != "":
                f.write(dish + ',' + idx + ',' + row['business_id'] + ',' +rel_sentences + '\n')

# %% [markdown]
# Reading the data we wrote back into a dataframe

# %%
dish_and_reviews = pd.read_csv("./output/dish_reviews.csv")
dish_and_reviews["sentences"] = dish_and_reviews["sentences"].map(lambda x: x[:-1].split('|'))

# %%
dish_and_reviews
# Out:
#                dish               review_id             business_id  \
# 0           dim sum  5f5Ep2WJ-CeNGXCDsq5VEQ  MvWxzyY3zIFH1fZL53E1yw
# 1           dim sum  Bgm7vT6X9PFBxzYHVvfNdQ  jbKVbSz51F8IcewsiRQu4A
# 2           dim sum  pSNvA6hVY0n994nOH0EaNg  9Qt1pt0pk2VWz0chdGk-jw
# 3           dim sum  _njEQDYNFeS6fiyFJX4C7w  9Qt1pt0pk2VWz0chdGk-jw
# 4           dim sum  JQ5-oEFiAiWAEwiXeN3VRg  yOYFhiTjT-SM4spKtDk92w
# ...             ...                     ...                     ...
# 17536  napa cabbage  i21Wt5HTbHk-z0oVpNaKgg  jgWAgT7LWPTf5wju9Q-kiw
# 17537  napa cabbage  1aMB8TMkf5EpnQ6NApClxQ  jgWAgT7LWPTf5wju9Q-kiw
# 17538  napa cabbage  7Ipe2TNwTl6gkcHHV3vdBA  8HCC8NuJmdHnEg2XC00NPg
# 17539  napa cabbage  PTlhdVvULEapTD46DfSGLw  2XmS09dl3GT_WknqS9hTVA
# 17540  napa cabbage  Ulp8vWWvc6QRnNBINjmUEQ  cXpMb3aCwMUsWikcXL7qJQ
#
#                                                sentences
# 0      [Madison has a place that serves up great dim ...
# 1      [sea bass) but I've only been for dim sum, One...
# 2      [*Review for dim sum only, part a la carte dim...
# 3      [says Phoenix Palace acquired a master dim sum...
# 4      [Ordering cooked-to-order dim sum off of a men...
# ...                                                  ...
# 17536   [- Steamed dumplings with pork and napa cabbage]
# 17537  [Tried ones with pork and napa cabbage and ste...
# 17538                                     [napa cabbage]
# 17539                                     [napa cabbage]
# 17540  [Had the napa cabbage dumplings which were abs...
#
# [17541 rows x 4 columns]

# %% [markdown]
# Now that we have the sentences split properly, we'll call the AWS comprehend APIs to give us the sentiment for each dish and review combination. Since the API returns 4 scores for each line, one for each type of sentiment(positive, negative, mixed, neutral) and we want a single metric to be able to compare and sort the dishes, I decided to take a weighted sum of the salient score for each line. Mixed scores were ignored since the sentiment was probably not obvious. Positive scores are added whereas negative scores are subtracted. Neutral scores were scaled down and added. The final score that will be generated will therefore be higher if its a positive review and lower if negative. These scores can then be used to sort the dishes.

# %%
comprehend = boto3.client(service_name='comprehend', region_name='ap-southeast-1')

def get_sentiment_score_aws(sentence_list):
    score = 0
    for sentence in sentence_list:
        result = comprehend.detect_sentiment(Text=sentence, LanguageCode='en')
        sentiment_info = result["SentimentScore"]
        if result["Sentiment"] == "POSITIVE":
            score = score + sentiment_info["Positive"]
        elif result["Sentiment"] == "NEGATIVE":
            score = score + sentiment_info["Negative"] * -1
        elif result["Sentiment"] == "NEUTRAL":
            score = score + sentiment_info["Neutral"] * 0.3
        else:
            score = score + 0
            #ignore the cases where the sentiment is mixed
        
    return score

# %%
dish_and_reviews["sentiment_score"] = dish_and_reviews["sentences"].map(get_sentiment_score_aws)

# %%
dish_and_reviews
# Out:
#                dish               review_id             business_id  \
# 0           dim sum  5f5Ep2WJ-CeNGXCDsq5VEQ  MvWxzyY3zIFH1fZL53E1yw
# 1           dim sum  Bgm7vT6X9PFBxzYHVvfNdQ  jbKVbSz51F8IcewsiRQu4A
# 2           dim sum  pSNvA6hVY0n994nOH0EaNg  9Qt1pt0pk2VWz0chdGk-jw
# 3           dim sum  _njEQDYNFeS6fiyFJX4C7w  9Qt1pt0pk2VWz0chdGk-jw
# 4           dim sum  JQ5-oEFiAiWAEwiXeN3VRg  yOYFhiTjT-SM4spKtDk92w
# ...             ...                     ...                     ...
# 17536  napa cabbage  i21Wt5HTbHk-z0oVpNaKgg  jgWAgT7LWPTf5wju9Q-kiw
# 17537  napa cabbage  1aMB8TMkf5EpnQ6NApClxQ  jgWAgT7LWPTf5wju9Q-kiw
# 17538  napa cabbage  7Ipe2TNwTl6gkcHHV3vdBA  8HCC8NuJmdHnEg2XC00NPg
# 17539  napa cabbage  PTlhdVvULEapTD46DfSGLw  2XmS09dl3GT_WknqS9hTVA
# 17540  napa cabbage  Ulp8vWWvc6QRnNBINjmUEQ  cXpMb3aCwMUsWikcXL7qJQ
#
#                                                sentences  sentiment_score
# 0      [Madison has a place that serves up great dim ...         0.259460
# 1      [sea bass) but I've only been for dim sum, One...         0.458380
# 2      [*Review for dim sum only, part a la carte dim...         0.807433
# 3      [says Phoenix Palace acquired a master dim sum...         0.995324
# 4      [Ordering cooked-to-order dim sum off of a men...         0.786310
# ...                                                  ...              ...
# 17536   [- Steamed dumplings with pork and napa cabbage]         0.297442
# 17537  [Tried ones with pork and napa cabbage and ste...         0.252151
# 17538                                     [napa cabbage]         0.297876
# 17539                                     [napa cabbage]         0.297876
# 17540  [Had the napa cabbage dumplings which were abs...         0.998676
#
# [17541 rows x 5 columns]

# %% [markdown]
# The now that we have the scores from the reviews we also would like to incorporate the information of the user who provided the review and also the upvotes on the review. The intuition here is that users who have a large number of followers are probably food connoisseurs who are regular users of the platform and hence their reviews should be given more weightage. Also, reviews which have garnered a lot of upvotes are also likely of high quality. In order to bring this information in we'll first have to join with our *complete_data* table that has that information

# %%
reviews_with_scores = complete_data.merge(dish_and_reviews, how="inner", on="review_id")
reviews_with_scores
# Out:
#                     review_id                 user_id  stars_rev  \
# 0      ZYaS2P5EmK9DANxGTV48Tw  u5xcw6LCnnMhddoxkRIgUA          5
# 1      nFPe7kazeEVjPP7zgoK4Og  iOPfu26Siat3sx-8SM63OQ          5
# 2      _Ev8oZvNjOeZLpWlu66QDg  hJbhbqg-x3TFzhvqqwl5RA          4
# 3      _Ev8oZvNjOeZLpWlu66QDg  hJbhbqg-x3TFzhvqqwl5RA          4
# 4      pV8vej4lot9N8wSRCBE7Yw  R04P35fYVS4HASyBuMcElg          4
# ...                       ...                     ...        ...
# 17536  UYkuV1_oxMCWImvNofyfgA  r1cO2JxQr8heDbkwNBnmIw          4
# 17537  ANiVL-pZQuC8Pl1KtOwCpA  n7SG66zQG_w-0y2W4jURIg          5
# 17538  ANiVL-pZQuC8Pl1KtOwCpA  n7SG66zQG_w-0y2W4jURIg          5
# 17539  eY0JzbLw-v8FFqVJ59IF5Q  Dr5hwEis0kRqHSZyNd00Kg          4
# 17540  GCNMuWjMTPuscr2NmZ947Q  pMXXX6AbUXgivkju9S7YDQ          5
#
#                 business_id_x  tot_votes  \
# 0      RgDg-k9S5YD_BaxMckifkg          0
# 1      UgjVZTSOaYoEvws_lAP_Dw          1
# 2      MKsb2VpLB-0UBODcInDsSw          1
# 3      MKsb2VpLB-0UBODcInDsSw          1
# 4      yXBo7Wgos9B-KzkYSMrNJw          9
# ...                       ...        ...
# 17536  MJLe4pP-0ZOFHuFt0CIoRw          4
# 17537  kiA-L7r9uHh2bqUPxuCzNQ          6
# 17538  kiA-L7r9uHh2bqUPxuCzNQ          6
# 17539  kiA-L7r9uHh2bqUPxuCzNQ          7
# 17540  kiA-L7r9uHh2bqUPxuCzNQ          3
#
#                                        categories        city  \
# 0                          {Restaurants, Chinese}   De Forest
# 1                          {Restaurants, Chinese}  Mc Farland
# 2                          {Restaurants, Chinese}   Middleton
# 3                          {Restaurants, Chinese}   Middleton
# 4                          {Restaurants, Chinese}     Madison
# ...                                           ...         ...
# 17536                      {Restaurants, Chinese}   Las Vegas
# 17537  {Restaurants, Thai, Asian Fusion, Chinese}   Las Vegas
# 17538  {Restaurants, Thai, Asian Fusion, Chinese}   Las Vegas
# 17539  {Restaurants, Thai, Asian Fusion, Chinese}   Las Vegas
# 17540  {Restaurants, Thai, Asian Fusion, Chinese}   Las Vegas
#
#                                name state  stars_res  \
# 0       Chang Jiang Chinese Kitchen    WI        4.0
# 1      Main Moon Chinese Restaurant    WI        3.5
# 2                  China Wok Buffet    WI        2.5
# 3                  China Wok Buffet    WI        2.5
# 4                      DumplingHaus    WI        3.5
# ...                             ...   ...        ...
# 17536      A & K Chinese Restaurant    NV        4.0
# 17537                Oriental House    NV        4.5
# 17538                Oriental House    NV        4.5
# 17539                Oriental House    NV        4.5
# 17540                Oriental House    NV        4.5
#
#                                                   review  review_count  \
# 0      [I really like both Chinese restaurants in tow...            21
# 1      [Main Moon has the best lunch in McFarland, bu...             3
# 2      [The china wok buffet is the best Chinese buff...             6
# 3      [The china wok buffet is the best Chinese buff...             6
# 4      [The Wife and I decided to try DumplingHaus at...           114
# ...                                                  ...           ...
# 17536  [Simply, some of the best Chinese food in Las ...             9
# 17537  [I decided to give the Oriental House a try be...            64
# 17538  [I decided to give the Oriental House a try be...            64
# 17539  [My friends and I decided to try this place ou...             3
# 17540  [Stopped by on 7-12-2014 by chance after simpl...            25
#
#                                                  friends  fans          dish  \
# 0       [Xiprzd4TvJcZnVHGPdDh1A, vNMHIyT76krWH3LXevQ96A]     1  crab rangoon
# 1                                                     []     0    fried rice
# 2       [tBctER6R_riVNVBAQBCOYA, tF1qQ5Ik8tb1xtXcU-eW_A]     0    deep fried
# 3       [tBctER6R_riVNVBAQBCOYA, tF1qQ5Ik8tb1xtXcU-eW_A]     0      egg roll
# 4      [k71n8bELfnhMeC63xhUxzw, TAOoRCZFOyySXWfOSaLQi...     7   green onion
# ...                                                  ...   ...           ...
# 17536  [_y7Hgs3-uT4uWGMRvCTExg, Kx4v-rKmNLZB0xdwfoAsS...     0    fried rice
# 17537  [5663s_8d6zqCXh4CS8a0LA, 67SeYDp8jKWsg2desVQk1...     1    fried rice
# 17538  [5663s_8d6zqCXh4CS8a0LA, 67SeYDp8jKWsg2desVQk1...     1   noodle soup
# 17539                                                 []     0      iced tea
# 17540                                                 []     0  papaya salad
#
#                 business_id_y  \
# 0      RgDg-k9S5YD_BaxMckifkg
# 1      UgjVZTSOaYoEvws_lAP_Dw
# 2      MKsb2VpLB-0UBODcInDsSw
# 3      MKsb2VpLB-0UBODcInDsSw
# 4      yXBo7Wgos9B-KzkYSMrNJw
# ...                       ...
# 17536  MJLe4pP-0ZOFHuFt0CIoRw
# 17537  kiA-L7r9uHh2bqUPxuCzNQ
# 17538  kiA-L7r9uHh2bqUPxuCzNQ
# 17539  kiA-L7r9uHh2bqUPxuCzNQ
# 17540  kiA-L7r9uHh2bqUPxuCzNQ
#
#                                                sentences  sentiment_score
# 0                [This one has outstanding crab rangoon]         0.992379
# 1                            [Their fried rice is legit]         0.562663
# 2                                    [deep fried shrimp]         0.268454
# 3                                            [egg rolls]         0.212986
# 4                                         [green onions]         0.297165
# ...                                                  ...              ...
# 17536  [We also had fried rice and a crispy noodle wi...         0.253102
# 17537                              [Hawaiian fried rice]         0.297853
# 17538  [Everything from Lemon Grass Chicken to Chaba ...         0.290666
# 17539  [and was even so generous enough to give us fr...         0.991410
# 17540      [We ordered papaya salad that was to dye for]         0.287109
#
# [17541 rows x 18 columns]

# %% [markdown]
# Now we want to scale the sentiment scores by the log(upvotes + fans). HAd to add the 2 to ensure that if the sum of fans and tot_votes is zero then the score won't change

# %%
reviews_with_scores["sentiment_score"] = reviews_with_scores["sentiment_score"] * np.log2(2 + reviews_with_scores["fans"] + reviews_with_scores["tot_votes"])
reviews_with_scores["sentiment_score"]
# Out:
# 0        0.992379
# 1        0.562663
# 2        0.268454
# 3        0.212986
# 4        1.214653
#            ...
# 17536    0.587684
# 17537    0.893559
# 17538    0.871999
# 17539    2.974230
# 17540    0.574219
# Name: sentiment_score, Length: 17541, dtype: float64

# %% [markdown]
# Now we are ready to analyse the sentiments. We can:
# * __Group by dishes__ and figure out which dishes are the most popular for the cuisine.
# * __Group by restaurants__ and extract the dishes that are most popular for a given restaurant
#
# Once we have both the above we can recommend restaurants to people who desire to try a new cuisine based on which dishes are popular and where we coud have them
#
# ### Grouping by dishes

# %%
gb_dishes = reviews_with_scores.loc[:, ["dish", "sentiment_score"]].groupby("dish")
popular_dishes = gb_dishes.mean()
popular_dishes = popular_dishes.sort_values(by="sentiment_score", ascending=False)

# %%
popular_dishes.head(10)
# Out:
#               sentiment_score
# dish
# filet mignon         2.257040
# pork belly           1.864442
# oyster sauce         1.759486
# hot pot              1.599117
# napa cabbage         1.411926
# san gabriel          1.214227
# sea bass             1.171565
# iced tea             1.104736
# peking duck          1.074820
# papaya salad         1.054830

# %% [markdown]
# ### Grouping by restaurant and dishes

# %%
gb_restaurants = reviews_with_scores.loc[:, ["name", "dish", "sentiment_score"]].groupby(["name", "dish"])
best_dishes_rest = gb_restaurants.mean()
best_dishes_rest
# Out:
#                                       sentiment_score
# name                   dish
# 1 Eastern Super Buffet chicken wings         3.389887
#                        crab legs            -1.771453
#                        crab rangoon          0.982680
#                        dim sum               1.068423
#                        egg roll             -5.446799
# ...                                               ...
# Zushi Japanese Bistro  soy sauce             2.494965
# iKitchen               fried rice            0.299289
#                        green onion          -0.255580
#                        noodle soup           0.490711
#                        soy sauce             0.000000
#
# [5331 rows x 1 columns]
