# %%
import pandas as pd
import sklearn.ensemble as ske
from sklearn.tree import DecisionTreeClassifier
import sklearn
import utils
import numpy as np

# %%
from gensim.test.utils import common_texts
from gensim.sklearn_api import D2VTransformer

# %%
features = pd.read_csv("./output/data.csv", index_col=0)
features
# Out:
#        pincode  review_count    rating  Szechuan  Indonesian  Pakistani  \
# 0        98118             4  4.000000     False       False      False
# 1        98109            21  4.047619     False       False      False
# 2        98103            14  3.111111     False       False      False
# 3        98112            42  4.088889     False       False      False
# 4        98102            12  3.071429     False       False      False
# ...        ...           ...       ...       ...         ...        ...
# 13294    98104             1  3.000000     False       False      False
# 13295    98116            29  4.258065     False       False      False
# 13296    98104             1  4.000000     False       False      False
# 13297    98109             2  4.000000     False       False      False
# 13298    98108             2  3.000000     False       False      False
#
#        Brazilian  Fondue  Latin American  Halal  ...  Chinese  Spanish  \
# ...

# %%
with open("./Hygiene/hygiene.dat", "r", encoding="utf-8") as rv_file:
    reviews = pd.Series([line.strip() for line in rv_file])

# %%
model = D2VTransformer(min_count=1, size=5)
model.transform(reviews)
#docvecs = []
#for r in reviews:
#    docvecs.append(model.fit_transform(r))
#docvecs
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-9-72c03d0d99f5> in <module>
#       1 model = D2VTransformer(min_count=1, size=5)
# ----> 2 model.transform(reviews)
#       3 #docvecs = []
#       4 #for r in reviews:
#       5 #    docvecs.append(model.fit_transform(r))
#
# ~\Anaconda3\lib\site-packages\gensim\sklearn_api\d2vmodel.py in transform(self, docs)
#     192         if self.gensim_model is None:
#     193             raise NotFittedError(
# --> 194                 "This model has not been fitted yet. Call 'fit' with appropriate arguments before using this method."
#     195             )
#     196
#
# NotFittedError: This model has not been fitted yet. Call 'fit' with appropriate arguments before using this method.

# %%
features = np.hstack((docvecs, features[["pincode", "review_count", "rating", "hygiene_sentiment"]].to_numpy()))
features
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-cbde149d10d0> in <module>
# ----> 1 features = np.hstack((docvecs, features.to_numpy()))
#       2 features
#
# ~\Anaconda3\lib\site-packages\numpy\core\shape_base.py in hstack(tup)
#     338         return _nx.concatenate(arrs, 0)
#     339     else:
# --> 340         return _nx.concatenate(arrs, 1)
#     341
#     342
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly
